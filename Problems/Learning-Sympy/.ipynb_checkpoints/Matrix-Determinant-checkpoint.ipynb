# %% [markdown]
# # Part B Problem
#
# Let $B_n$ denote that $n \times n$ matrix with $(i, j)$'th enntry equal to:
#
#
# $$
# \begin{aligned}
# b_{ij} = \begin{cases}
# \frac{1}{2j- i^2}, &\text{ if } i > j \\
# \frac{i}{i- j}+  \frac{1}{n^2- j - i}, &\text{ if } j>i \\
# 0 &\text{ if } i = j
# \end{cases}
# \end{aligned}
# $$
#
#
#
# Look at the numerical values of the determinant of $B_n$ for $3≤n≤30$ and display these values graphically. You should observe that the values seem to follow a pattern.
#
#   Look at the sequence and show  that  the  $n-\log{}$  or  $\log$-$\log$  transformation  gives  a  fit  that  is  approximately  linear  and  hence obtain  and  test  a  formula  that  predicts  the  value  of  the  sequence.   Define  a  function  that  predicts the value of the determinant of $Bn$.
#
# What is the largest percentage error that your formula has for $30≤n≤50$?

# %% [markdown]
# ## Preamble

# %%
from __future__ import division
from sympy import *
x, y, z, t = symbols('x y z t')
k, m, n = symbols('k m n', integer=True)
f, g, h = symbols('f g h', cls=Function)
init_printing()

# Printing
init_printing(use_latex='mathjax', latex_mode='equation')

# Clipboard
import pyperclip
def lx(expr):
    pyperclip.copy(latex(expr))
    print(expr)

# %% [markdown]
# ## Create the Matrix

# %% [markdown]
# Expressions in `Sympy` are generally immutable, matrices are the exception to this. A consequence of this is that attributes of matrix objects **occur in place**.

# %% [markdown]
# In order to generate an empty matrix the `zeros` function can be used:

# %%
n = 2
mymat = zeros(n, n)
mymat
# mymat.row(2)[1] = 7
# Out:
# ⎡0  0⎤
# ⎢    ⎥
# ⎣0  0⎦

# %% [markdown]
# Then the values of the matrix may be modified by looping through the array:

# %%
for i in range(mymat.shape[0]):
    for j in range(mymat.shape[1]):
        print("(" + str(i) + "," + str(j) + ")")
# Out:
# (0,0)
# (0,1)
# (1,0)
# (1,1)

# %% [markdown]
# and so to assign the values based on the condition in the problem:

# %%
def BuildMat(n):
    mymat = zeros(n,n)
    for i in range(n):
        for j in range(n):
            # Increment i and j by one because they count from zero
            i += 1; j += 1
            if (i > j):
                v = 1/(2*j - i**2)
            elif (j > i):
                v = 1/(i-j) + 1/(n**2 - j - i)
            else:
                v = 0
            # Decrement i and j so the index lines up
            i -= 1; j -= 1
            mymat[j, i] = v
    return mymat

BuildMat(3)
# Out:
# ⎡        0           -0.5   -0.142857142857143⎤
# ⎢                                             ⎥
# ⎢-0.833333333333333    0           -0.2       ⎥
# ⎢                                             ⎥
# ⎣       -0.3         -0.75          0         ⎦

# %% [markdown]
# ## Find the Determinant

# %%
def detMat(n):
    return Determinant(BuildMat(n)).doit()
detMat(2)

Determinant(BuildMat(3)).simplify()
# Out:
# -0.119285714285714

# %% [markdown]
# ## Find the Determinant of Various Values

# %%
# We double all numbers using map() 
result = map(detMat, range(30)) 
# print(list(result))
[round(num, 3) for num in list(result)]
# Out:
# [1, 0, 0, -0.119, -0.035, -0.018, -0.013, -0.01, -0.008, -0.006, -0.005, -0.00
# 4, -0.004, -0.003, -0.003, -0.002, -0.002, -0.002, -0.002, -0.001, -0.001, -0.
# 001, -0.001, -0.001, -0.e-3, -0.e-3, -0.e-3, -0.e-3, -0.e-3, -0.e-3]

# %% [markdown]
# ### Create a Data Frame

# %%
import pandas as pd

data = {'Matrix.Size': range(30),
        'Determinant.Value': list(map(detMat, range(30)))
}



df = pd.DataFrame(data)

print(df)
# Out:
# Matrix.Size      Determinant.Value
# 0             0                      1
# 1             1                      0
# 2             2                      0
# 3             3     -0.119285714285714
# 4             4    -0.0352575763181824
# 5             5    -0.0180622054313475
# 6             6    -0.0130234795781754
# 7             7   -0.00995884317994898
# 8             8   -0.00782184559014832
# 9             9   -0.00628840304169881
# 10           10   -0.00515839836598470
# 11           11   -0.00430448116137098
# 12           12   -0.00364462792217378
# 13           13   -0.00312470891044082
# 14           14   -0.00270804216246506
# 15           15   -0.00236913494508374
# 16           16   -0.00208985860358642
# 17           17   -0.00185705171809406
# 18           18   -0.00166097999794876
# 19           19   -0.00149432281296443
# 20           20   -0.00135149140850168
# 21           21   -0.00122816088486413
# 22           22   -0.00112094292575809
# 23           23   -0.00102715304986957
# 24           24  -0.000944642506540081
# 25           25  -0.000871675127336310
# 26           26  -0.000806835927146135
# 27           27  -0.000748962449051095
# 28           28  -0.000697092617269676
# 29           29  -0.000650424718935463

# %% [markdown]
# ### Plot the Data frame

# %%
from plotnine import *

ggplot(df, aes(x = 'Matrix.Size', y = 'Determinant.Value')) + geom_point()
# Out:
# <ggplot: (8777382466949)>

# %% [markdown]
# ## Log Transform the Data

# %%
# pyperclip.copy(df.columns[0])
df['Determinant.Value'] = [ log(-val).expand(force = True) for val in df['Determinant.Value']]
df
# Out:
#     Matrix.Size  Determinant.Value
# 0             0               I*pi
# 1             1                zoo
# 2             2                zoo
# 3             3  -2.12623370318660
# 4             4  -3.34507484180595
# 5             5  -4.01393362154157
# 6             6  -4.34100142919850
# 7             7  -4.60929436072264
# 8             8  -4.85083474330028
# 9             9  -5.06904812894707
# 10           10  -5.26712914185992
# 11           11  -5.44809866837230
# 12           12  -5.61450099769660
# 13           13  -5.76841414879132
# 14           14  -5.91152935445765
# 15           15  -6.04523039253894
# 16           16  -6.17065886908044
# 17           17  -6.28876514665255
# 18           18  -6.40034749059762
# 19           19  -6.50608214267721
# 20           20  -6.60654654927747
# 21           21  -6.70223744410573
# 22           22  -6.79358504987417
# 23           23  -6.88096433297585
# 24           24  -6.96470400200160
# 25           25  -7.04509376386730
# 26           26  -7.12239022245160
# 27           27  -7.19682171048209
# 28           28  -7.26859227616109
# 29           29  -7.33788499470954

# %%
from plotnine import *

ggplot(df, aes(x = 'Matrix.Size', y = 'Determinant.Value')) + geom_point()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /usr/lib/python3.8/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# /usr/lib/python3.8/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/.local/lib/python3.8/site-packages/plotnine/ggplot.py in __repr__(self)
#      86         # in the jupyter notebook.
#      87         if not self.figure:
# ---> 88             self.draw()
#      89         plt.show()
#      90         return '<ggplot: (%d)>' % self.__hash__()
#
# ~/.local/lib/python3.8/site-packages/plotnine/ggplot.py in draw(self, return_ggplot)
#     179         # new frames knowing that they are separate from the original.
#     180         with pd.option_context('mode.chained_assignment', None):
# --> 181             return self._draw(return_ggplot)
#     182
#     183     def _draw(self, return_ggplot=False):
#
# ~/.local/lib/python3.8/site-packages/plotnine/ggplot.py in _draw(self, return_ggplot)
#     186         # assign a default theme
#     187         self = deepcopy(self)
# --> 188         self._build()
#     189
#     190         # If no theme we use the default
#
# ~/.local/lib/python3.8/site-packages/plotnine/ggplot.py in _build(self)
#     293         # Map and train positions so that statistics have access
#     294         # to ranges and all positions are numeric
# --> 295         layout.train_position(layers, scales.x, scales.y)
#     296         layout.map_position(layers)
#     297
#
# ~/.local/lib/python3.8/site-packages/plotnine/facets/layout.py in train_position(self, layers, x_scale, y_scale)
#      86             self.panel_scales_y = result.y
#      87
# ---> 88         self.facet.train_position_scales(self, layers)
#      89
#      90     def map_position(self, layers):
#
# ~/.local/lib/python3.8/site-packages/plotnine/facets/facet.py in train_position_scales(self, layout, layers)
#     233                 # the scale index for each data point
#     234                 SCALE_Y = _layout['SCALE_Y'].iloc[match_id].tolist()
# --> 235                 panel_scales_y.train(data, y_vars, SCALE_Y)
#     236
#     237         return self
#
# ~/.local/lib/python3.8/site-packages/plotnine/scales/scales.py in train(self, data, vars, idx)
#     120             for i, sc in enumerate(self, start=1):
#     121                 bool_idx = (i == idx)
# --> 122                 sc.train(data.loc[bool_idx, col])
#     123
#     124     def map(self, data, vars, idx):
#
# ~/.local/lib/python3.8/site-packages/plotnine/scales/scale_xy.py in train(self, series)
#      67             self.range_c.train(series)
#      68         else:
# ---> 69             self.range.train(series, drop=self.drop)
#      70
#      71     def map(self, series, limits=None):
#
# ~/.local/lib/python3.8/site-packages/plotnine/scales/range.py in train(self, x, drop, na_rm)
#      41         Train discrete range
#      42         """
# ---> 43         self.range = scale_discrete.train(x, self.range, drop, na_rm=na_rm)
#
# ~/.local/lib/python3.8/site-packages/mizani/scale.py in train(cls, new_data, old, drop, na_rm)
#     214                 new = list(categories)
#     215         else:
# --> 216             new = np.unique(new_data)
#     217             new.sort()
#     218
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /usr/lib/python3.8/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     259     ar = np.asanyarray(ar)
#     260     if axis is None:
# --> 261         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     262         return _unpack_tuple(ret)
#     263
#
# /usr/lib/python3.8/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     320         aux = ar[perm]
#     321     else:
# --> 322         ar.sort()
#     323         aux = ar
#     324     mask = np.empty(aux.shape, dtype=np.bool_)
#
# ~/.local/lib/python3.8/site-packages/sympy/core/numbers.py in __lt__(self, other)
#    1471         rv = self._Frel(other, mlib.mpf_lt)
#    1472         if rv is None:
# -> 1473             return Expr.__lt__(self, other)
#    1474         return rv
#    1475
#
# ~/.local/lib/python3.8/site-packages/sympy/core/expr.py in __lt__(self, other)
#     403     def __lt__(self, other):
#     404         from sympy import StrictLessThan
# --> 405         return self._cmp(other, "<", StrictLessThan)
#     406
#     407     def __trunc__(self):
#
# ~/.local/lib/python3.8/site-packages/sympy/core/expr.py in _cmp(self, other, op, cls)
#     344         for me in (self, other):
#     345             if me.is_extended_real is False:
# --> 346                 raise TypeError("Invalid comparison of non-real %s" % me)
#     347             if me is S.NaN:
#     348                 raise TypeError("Invalid NaN comparison")
#
# TypeError: Invalid comparison of non-real I*pi
